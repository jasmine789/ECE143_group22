# %%
from age_distribution_plot import age_distribution, age_distribution_gender,age_distribution_races
import warnings
warnings.filterwarnings('ignore')

# %%
fileName = 'MergeCommon_final.csv'
age_distribution(fileName)

# %%
age_distribution_races(fileName)

# %%
fig_sns_gender = age_distribution_gender(fileName)
